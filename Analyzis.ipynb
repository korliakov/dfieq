# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("numbers.txt").T

x = data[0]
t = data[-1]

print(x)
# Out:
# [1.00000e+00 1.00000e+00 1.00000e+00 ... 1.10388e+09 1.10632e+09
#  1.10876e+09]

# %%
plt.plot(t, x)

plt.show()
