# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("numbers.txt").T

x = data[0]
t = data[-1]

print(x)
# Out:
# [1.       1.       0.99955  ... 0.426975 0.417715 0.408406]

# %%
plt.plot(t, x)

plt.show()
