# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("numbers.txt").T

x = data[0]
t = data[-1]

print(x)
# Out:
# [0.99995  0.9998   0.99955  ... 0.846742 0.85202  0.857212]

# %%
plt.plot(t, x)
plt.plot(t, np.cos(t))
plt.show()
